# %% [markdown]
# Linear Regression

# %%
import matplotlib.pyplot as plt

x = [4,3,3,3,6,4,5,4,5,1,2,2,3]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]
plt.xlabel("Years of experience")
plt.ylabel("Annual salary in dollars")
plt.scatter(x, y)
plt.show()

# %%
import matplotlib.pyplot as py
from scipy import stats

x = [4,3,3,3,6,4,5,4,5,1,2,2,3]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

# %%
stats.linregress(x,y)
# Out:
# LinregressResult(slope=6.129139072847683, intercept=68.55298013245033, rvalue=0.8849703224497456, pvalue=5.810623905098733e-05, stderr=0.9723701896495628, intercept_stderr=3.6081657138701346)

# %%
slope,intercept,r,p,std_err=stats.linregress(x,y)

# %%
slope
# Out:
# 6.129139072847683

# %%
r
# Out:
# 0.8849703224497456

# %%
def myfunc(x):
    return slope * x + intercept
map(myfunc,x)

# %%
mymodel = list(map(myfunc,x))

# %%
plt.scatter(x, y) ## scatter plot
plt.plot(x, mymodel) ## line plot
plt.show()

# %%
import matplotlib.pyplot as plt
from scipy import stats

x = [89,43,36,36,95,10,66,34,38,20,26,29,48,64,6,5,36,66,72,40]
y = [21,46,3,35,67,95,53,72,58,10,26,34,90,33,38,20,56,2,47,15]
plt.scatter(x, y)
plt.show()

# %%
x=stats.linregress(x,y)

# %%
x.rvalue
# Out:
# 0.013318141542974915
